# %%
from sklearn.linear_model import LinearRegression
import numpy as np
X=np.array([[1],[2],[3],[4],[5]])
y=np.array([[10],[20],[30],[40],[50]])
model= LinearRegression()
model.fit(X,y)
print("slope:",model.coef_)
print("intercept:",model.intercept_)
print("Model Prediction",model.predict([[4]]))
# Out:
# slope: [[10.]]
# intercept: [-7.10542736e-15]
# Model Prediction [[40.]]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np

df = pd.read_csv(r"C:\Users\venne\Downloads\data.csv")
le = LabelEncoder()
df["city"] = le.fit_transform(df["city"])
x = df[["bedrooms", "bathrooms", "city"]]
y = df["price"]
model = LinearRegression()
model.fit(x, y)
city_value = le.transform(["Redmond"])[0]
prediction = model.predict([[2, 2, city_value]])
print("predicted price:", prediction)
# Out:
# predicted price: [497219.69685055]
# C:\Users\venne\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
